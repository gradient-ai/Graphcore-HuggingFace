# %% [markdown]
# # Training HuggingFace 🤗 Models on an IPU using Paperspace Gradient
#
# Whether you are looking to generate images with Stable Diffusion, derive insights from text, or need to recognize audio samples, the examples in here have you covered. And by using Paperspace to access IPUs you can be up and running in minutes!
#
# ## Getting Started with our interactive notebooks
#
# You will learn how to use IPUs in a Jupyter-style notebook. Amongst other applications, you will be able to use IPUs to train models including vision transformers (ViT) for images, BERT-Large for question answering, and text classification.
#
# ## Graphcore Hugging Face models
#
# To familurise yourself with IPU related programming start here with our [Introduction to 🤗 Optimum Graphcore: BERT Fine-tuning on IPUs](natural-language-processing/introduction_to_optimum_graphcore.ipynb) notebook.
#
# For dedicated finetuning, inference, advanced ML and IPU related notebooks checkout the following notebooks:

# %% [markdown]
# <details><summary><big> Fine-tune our models on your datasets</summary><br/>
# Here are our notebooks on how to use datasets to fine-tune HuggingFace checkpoints.
#
# Interested in <b>audio processing</b>? Check out [how to fine-tune a pre-trained wav2vec 2.0 model with PyTorch on the IPU.](audio-processing/wav2vec2-fine-tuning-checkpoint.ipynb)
#
# This <b>image classification</b> notebook will show you how to preprocess the data and fine-tune a pretrained model on image classification.
#
# ### Natural Language Processing
#
# Check out our NLP notebooks to help you get you started on fine-tuning your models for a range of different tasks. Show how to preprocess the data and fine-tune a pretrained model on:
# <ul style=“list-style-type:disc”>
#
# *  WMT in our [translation notebook](natural-language-processing/translation.ipynb),
#
# *  SWAG in our [multiple choice notebook](natural-language-processing/other-use-cases/multiple_choice.ipynb),
#
# *  SQUAD in our [question-answering notebook](/natural-language-processing/other-use-cases/question_answering.ipynb),
#
# *  any GLUE task in our [text_classification notebook](natural-language-processing/other-use-cases/text_classification.ipynb),
#
# *  the CONLL 2003 dataset, in our [token classification notebook (NER, PoS).](natural-language-processing/other-use-cases/token_classification.ipynb)
# </ul>
#
#
# </details>

# %% [markdown]
# <details><summary><big> Use 🤗 model checkpoints for inference</summary>
#
# Here you can learn how to use Hugging Face checkpoints directly for inference.
# * [Introduction to 🤗 Optimum Graphcore: BERT Fine-tuning on IPUs](natural-language-processing/introduction_to_optimum_graphcore.ipynb) uses a BERT model to introduce the process of running on the IPU. This could be a good starting point to get familiar with the IPU, even if this isn’t your main area of interest. It has a good introduction to pipelining an application across multiple IPUs.
# * To run inference on <b>audio segments</b> checkout our [wav2vec2 notebook for inference](audio-processing/wav2vec2-inference-checkpoint.ipynb) on how to run inference on the wav2vec 2.0 model with PyTorch
#
# ### Natural Language Processing
#
# Our NLP notebooks show how to run inference with only 2 lines of code!
#
# - Use the sentiment-analysis pipeline to quickly evaluate pre-trained models on the IPU in our [sentiment analysis notebook](natural-language-processing/sentiment_analysis.ipynb)
# - Use Gradio and pipelines to prototype a web application doing fast token classification in our [name entity extraction notebook](natural-language-processing/name-entity-extraction.ipynb).
#
# </details>

# %% [markdown]
# <details><summary><big> Build your own models</summary>
#
# Interested in porting your own models onto the Hugging Face platform? Then you're in the right place.
#
# Check out our notebooks on how to do exactly that:
# <ul style=“list-style-type:disc”>
#
# - Show how to train a model for [causal or masked language modelling from scratch](natural-language-processing/other-use-cases/language_modelling_from_scratch.ipynb),
#
# - Learn [how to train an external model](natural-language-processing/other-use-cases/external_model.ipynb) that is not supported by Optimum or Transformers.
# </ul>
# </details>

# %% [markdown]
# <details><summary><big> Stable Diffusion</summary>
#
# Explore our more advanced examples with our range of Stable Diffusion notebooks!
# <ul style=“list-style-type:disc”>
#
# * Run a Stable Diffusion 2 (Conditional UNet) pipeline on the [text-to-image generation task.](stable-diffusion/text_to_image_sd2.ipynb)
#
# * Run a Stable Diffusion (Conditional UNet) pipeline on the [text-to-image generation task](stable-diffusion/text_to_image.ipynb),
#
# * Run a Stable Diffusion (Conditional UNet) pipeline on the [image-to-image generation task.](stable-diffusion/image_to_image.ipynb)
#
# * Run a Stable Diffusion (Conditional UNet) pipeline on the [inpainting task](stable-diffusion/inpainting.ipynb)
# </ul>
# </details>

# %% [markdown]
# ### Useful tips
# Finally, the [Managing IPU resources](useful-tips/managing_ipu_resources.ipynb) notebook contains information about how to make best use of the IPU resources. For example monitoring IPU use, releasing IPUs when you are not using them, and then re-attaching your model to the IPU when you start again.
